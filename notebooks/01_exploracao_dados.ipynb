# %% [markdown]
# # JobMatch AI - Exploração de Dados
#
# Notebook inicial para análise dos datasets, limpeza dos textos e validação das hipóteses do projeto.

# %%
import pandas as pd
from pathlib import Path

DATA_RAW = Path('../data/raw')
DATA_PROCESSED = Path('../data/processed')

DATA_RAW, DATA_PROCESSED
